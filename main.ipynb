# %%
import streamlit as st
import pandas as pd

# %%
st.title("Euros 2024 Shots")

st.subheader("Filter to any team/player to see their shooting stats")
# Out:
# 2024-09-23 16:05:41.255 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-23 16:05:41.362
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/mahbub/anaconda3/envs/jupyter_env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-09-23 16:05:41.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-23 16:05:41.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-23 16:05:41.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
df = pd.read_csv("euros_2024_shot_map.csv")
df.head(3)
# Out:
#    50_50  bad_behaviour_card  ball_receipt_outcome  block_deflection  \
# 0    NaN                 NaN                   NaN               NaN
# 1    NaN                 NaN                   NaN               NaN
# 2    NaN                 NaN                   NaN               NaN
#
#    block_save_block  carry_end_location  clearance_aerial_won  \
# 0               NaN                 NaN                   NaN
# 1               NaN                 NaN                   NaN
# 2               NaN                 NaN                   NaN
#
#    clearance_body_part  clearance_head  clearance_left_foot  ...  \
# 0                  NaN             NaN                  NaN  ...
# 1                  NaN             NaN                  NaN  ...
# 2                  NaN             NaN                  NaN  ...
#
#    shot_saved_to_post  goalkeeper_success_in_play  ball_recovery_offensive  \
# 0                 NaN                         NaN                      NaN
# 1                 NaN                         NaN                      NaN
# 2                 NaN                         NaN                      NaN
#
#    dribble_no_touch  player_off_permanent  goalkeeper_penalty_saved_to_post  \
# 0               NaN                   NaN                               NaN
# 1               NaN                   NaN                               NaN
# 2               NaN                   NaN                               NaN
#
#    goalkeeper_shot_saved_off_target  shot_follows_dribble  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
#
#    shot_saved_off_target  shot_redirect
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
#
# [3 rows x 89 columns]
